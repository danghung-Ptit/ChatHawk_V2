# %%
print("ok")
# Out:
# ok

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("demo_wav_1.mp3")
print(result["text"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/ChatHawk_V2/lib/python3.9/site-packages/requests/compat.py:11
#      10 try:
# ---> 11     import chardet
#      12 except ImportError:
#
# ModuleNotFoundError: No module named 'chardet'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import whisper
#       3 model = whisper.load_model("base")
#       4 result = model.transcribe("demo_wav_1.mp3")
#
# File ~/miniforge3/envs/ChatHawk_V2/lib/python3.9/site-packages/whisper/__init__.py:12
#       9 from tqdm import tqdm
#      11 from .audio import load_audio, log_mel_spectrogram, pad_or_trim
# ---> 12 from .decoding import DecodingOptions, DecodingResult, decode, detect_language
# ...
